# %% [markdown]
# Python script by [__Hassan Mojeed__](https://www.linkedin.com/in/hassanmojeed)<br>
# Email: mojeed.o.hassan@gmail.com<br>
# Website: [https://hassanmojeed.pages.dev](https://hassanmojeed.pages.dev)
#
#
#
# # Page 3

# %% [markdown]
# ## Introduction
#
# ##### Continuing the study's progression, this phase involves web scraping data from Wikipedia to extract links to country flags essential for this research. This process is crucial for acquiring the necessary visual assets to enhance the analysis and presentation of findings.

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import os
import pandas_gbq
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Scrapping Country Flag links from wikipedia

# %%
# List to store tuples of country name and flag link
countryname_flaglnk = []

# URL of the Wikipedia page containing flags
url = "https://en.wikipedia.org/wiki/Gallery_of_sovereign_state_flags"

# Send an HTTP GET request to retrieve the page content
response_ok = requests.get(url)

# Parse the HTML content using BeautifulSoup
web_data = BeautifulSoup(response_ok.text, "html")

# Find all img elements with class "mw-file-element" (these are the flag images)
flaglnk_list = web_data.find_all("img", {"class": "mw-file-element"})

# Extract the src attribute of each img element and construct the flag link URLs
flaglnk = ["https:" + img["src"] for img in flaglnk_list][1:-2]

# Find all div elements with class "gallerytext" (these contain the country names)
country_list = web_data.find_all("div", {"class": "gallerytext"})

# Extract the text content (country names) from each div element
countryname = [element.text for element in country_list]

# Combine country names with corresponding flag links into a list of tuples
for row in zip(countryname, flaglnk):
    countryname_flaglnk.append(row)

# Create a DataFrame from the list of tuples with columns "Country" and "Flag Link"
country_flag = pd.DataFrame(countryname_flaglnk, columns=["Country", "Flag Link"])

# %%
# Removing some flag links that are not needed for this study

remove_flaglnks = [
"https://upload.wikimedia.org/wikipedia/commons/thumb/7/7a/Flag_of_the_Republic_of_Abkhazia.svg/120px-Flag_of_the_Republic_of_Abkhazia.svg.png",
"https://upload.wikimedia.org/wikipedia/commons/thumb/5/5c/Flag_of_the_Taliban.svg/120px-Flag_of_the_Taliban.svg.png",
"https://upload.wikimedia.org/wikipedia/commons/thumb/3/35/Flag_of_the_Cook_Islands.svg/120px-Flag_of_the_Cook_Islands.svg.png",
"https://upload.wikimedia.org/wikipedia/commons/thumb/1/1f/Flag_of_Kosovo.svg/120px-Flag_of_Kosovo.svg.png",
"https://upload.wikimedia.org/wikipedia/commons/thumb/0/01/Flag_of_Niue.svg/120px-Flag_of_Niue.svg.png",
"https://upload.wikimedia.org/wikipedia/commons/thumb/1/1e/Flag_of_the_Turkish_Republic_of_Northern_Cyprus.svg/120px-Flag_of_the_Turkish_Republic_of_Northern_Cyprus.svg.png",
"https://upload.wikimedia.org/wikipedia/commons/thumb/2/26/Flag_of_the_Sahrawi_Arab_Democratic_Republic.svg/120px-Flag_of_the_Sahrawi_Arab_Democratic_Republic.svg.png",
"https://upload.wikimedia.org/wikipedia/commons/thumb/4/4d/Flag_of_Somaliland.svg/120px-Flag_of_Somaliland.svg.png",
"https://upload.wikimedia.org/wikipedia/commons/thumb/1/12/Flag_of_South_Ossetia.svg/120px-Flag_of_South_Ossetia.svg.png",
"https://upload.wikimedia.org/wikipedia/commons/thumb/b/bc/Flag_of_Transnistria_%28state%29.svg/120px-Flag_of_Transnistria_%28state%29.svg.png"]


# Create an empty list to store filtered rows
filtered_rows = []

# Iterate through each row in the DataFrame
for index, row in country_flag.iterrows():
    flag_link = row["Flag Link"]
    # Check if the flag link is not in the remove_flaglnks list
    if flag_link not in remove_flaglnks:
        # Append the row to the filtered_rows list
        filtered_rows.append(row)

# Create a new DataFrame from the filtered rows
filtered_country_flag = pd.DataFrame(filtered_rows).reset_index(drop=True)

# Display the filtered DataFrame

print(filtered_country_flag.shape)

filtered_country_flag
# Out:
# (196, 2)
#                                   Country  \
# 0    Afghanistan (Islamic Republic of)[a]
# 1                                 Albania
# 2                                 Algeria
# 3                                 Andorra
# 4                                  Angola
# ..                                    ...
# 191                               Vietnam
# 192                                 Yemen
# 193                                Zambia
# 194                              Zimbabwe
# 195                                Taiwan
#
#                                              Flag Link
# 0    https://upload.wikimedia.org/wikipedia/commons...
# 1    https://upload.wikimedia.org/wikipedia/commons...
# 2    https://upload.wikimedia.org/wikipedia/commons...
# 3    https://upload.wikimedia.org/wikipedia/commons...
# 4    https://upload.wikimedia.org/wikipedia/commons...
# ..                                                 ...
# 191  https://upload.wikimedia.org/wikipedia/commons...
# 192  https://upload.wikimedia.org/wikipedia/commons...
# 193  https://upload.wikimedia.org/wikipedia/commons...
# 194  https://upload.wikimedia.org/wikipedia/commons...
# 195  https://upload.wikimedia.org/wikipedia/commons...
#
# [196 rows x 2 columns]

# %%
# renaming some of the country for conformity

filtered_country_flag["Country"].replace({
                                "Afghanistan (Islamic Republic of)[a]" : "Afghanistan",
                                "Brunei" : "Brunei Darussalam",
                                "Cape Verde" : "Cape Verde Islands",
                                "Comoros" : "Comoro Islands",
                                "Democratic Republic of the Congo" : "Congo (Dem. Rep.)",
                                "Republic of the Congo" : "Congo (Rep.)",
                                "Equitorial Guinea" : "Equatorial Guinea",
                                "East Timor" : "Timor-Leste",
                                "Ivory Coast" : "Cote d'Ivoire",
                                "Moldova" : "Republic of Moldova",
                                "Palau" : "Palau Islands",
                                "Palestine" : "State of Palestine",
                                "Russia" : "Russian Federation",
                                "São Tomé and Príncipe" : "Sao Tome and Principe",
                                "Vatican City" : "Vatican City(Holy See)",
                                "Taiwan" : "Taiwan (Chinese Taipei)"
                                },inplace=True
)


print(filtered_country_flag.shape)

filtered_country_flag.head()
# Out:
# (196, 2)
#        Country                                          Flag Link
# 0  Afghanistan  https://upload.wikimedia.org/wikipedia/commons...
# 1      Albania  https://upload.wikimedia.org/wikipedia/commons...
# 2      Algeria  https://upload.wikimedia.org/wikipedia/commons...
# 3      Andorra  https://upload.wikimedia.org/wikipedia/commons...
# 4       Angola  https://upload.wikimedia.org/wikipedia/commons...

# %%
# we need additional flag links for three more countries, since we could not get them from the initial web scraping appraoch above.

# List to store tuples of country name and flag link for dependent territories
missing_flaglnk = []

# URL of the Wikipedia page containing flags of dependent territories
url_new = "https://en.wikipedia.org/wiki/Gallery_of_flags_of_dependent_territories"

# Send an HTTP GET request to retrieve the page content
response = requests.get(url_new)

# Parse the HTML content using BeautifulSoup
web_info = BeautifulSoup(response.text, "html")

# Find all img elements with class "mw-file-element" (these are the flag images)
flnk_list = web_info.find_all("img", {"class": "mw-file-element"})

# Extract the src attribute of each img element and construct the flag link URLs
flnk = ["https:" + img["src"] for img in flnk_list]

# Find all div elements with class "gallerytext" (these contain the country names)
name_list = web_info.find_all("div", {"class": "gallerytext"})

# Extract the text content (country names) from each div element
name = [element.text for element in name_list]

# Combine country names with corresponding flag links into a list of tuples
for row in zip(name, flnk):
    missing_flaglnk.append(row)

# Create a DataFrame from the list of tuples with columns "Country" and "Flag Link"
flag_cnty = pd.DataFrame(missing_flaglnk, columns=["Country", "Flag Link"])

# Filter the DataFrame to select rows where the country name matches "Flag of Hong Kong" or "Flag of Macau"
filtered_flag_cnty = flag_cnty[(flag_cnty["Country"] == "Flag of Hong Kong") | (flag_cnty["Country"] == "Flag of Macau")]

# %%
filtered_flag_cnty["Country"].replace({"Flag of Hong Kong" : "Hong Kong (SAR China)",
                                        "Flag of Macau" : "Macao (SAR China)"},
                                        inplace=True)

filtered_flag_cnty.shape
# Out:
# (2, 2)

# %%
# last missing flag from the dataset

lst_missingflg_dic = {"Country" : "Kosovo", 
                  "Flag Link" : "https://upload.wikimedia.org/wikipedia/commons/thumb/1/1f/Flag_of_Kosovo.svg/238px-Flag_of_Kosovo.svg.png"}

lst_missingflg_df = pd.DataFrame([lst_missingflg_dic])

lst_missingflg_df.shape
# Out:
# (1, 2)

# %% [markdown]
# ## Combining all DataFrames into one DataFrame

# %%
country_and_flag = pd.concat([filtered_country_flag, filtered_flag_cnty, lst_missingflg_df]).reset_index(drop=True)

country_and_flag["Flag Link"] = country_and_flag["Flag Link"].astype(str)

print(country_and_flag.shape)

country_and_flag = country_and_flag.astype(str)

#country_and_flag.to_parquet("country_and_flag.parquet")

country_and_flag.to_excel("country_and_flag.xlsx")
# Out:
# (199, 2)

# %%
# writing data to Google Big Query

#table = "Country_Rank.Country and Flag"
#project_id = "cool-ship-407420"

#pandas_gbq.to_gbq(country_and_flag,destination_table=table, project_id=project_id, if_exists="replace")

# %% [markdown]
# ## Downloading all flags on local drive

# %%
# Create a directory to save the images if it doesn't exist
output_dir = "flag_images"
os.makedirs(output_dir, exist_ok=True)

# Function to download images
def download_image(url, filename):
    response = requests.get(url)
    if response.status_code == 200:
        with open(filename, 'wb') as f:
            f.write(response.content)
            print(f"Downloaded: {filename}")
    else:
        print(f"Failed to download: {filename}")

# %%
# Download images
for index, row in country_and_flag.iterrows():
    country = row["Country"]
    image_url = row["Flag Link"]
    filename = os.path.join(output_dir, f"{country}.png")
    download_image(image_url, filename)
# Out:
# Downloaded: flag_images/Afghanistan.png
# Downloaded: flag_images/Albania.png
# Downloaded: flag_images/Algeria.png
# Downloaded: flag_images/Andorra.png
# Downloaded: flag_images/Angola.png
# Downloaded: flag_images/Antigua and Barbuda.png
# Downloaded: flag_images/Argentina.png
# Downloaded: flag_images/Armenia.png
# Downloaded: flag_images/Australia.png
# Downloaded: flag_images/Austria.png
# Downloaded: flag_images/Azerbaijan.png
# Downloaded: flag_images/Bahamas.png
# Downloaded: flag_images/Bahrain.png
# Downloaded: flag_images/Bangladesh.png
# Downloaded: flag_images/Barbados.png
# Downloaded: flag_images/Belarus.png
# Downloaded: flag_images/Belgium.png
# Downloaded: flag_images/Belize.png
# Downloaded: flag_images/Benin.png
# Downloaded: flag_images/Bhutan.png
# Downloaded: flag_images/Bolivia.png
# Downloaded: flag_images/Bosnia and Herzegovina.png
# Downloaded: flag_images/Botswana.png
# Downloaded: flag_images/Brazil.png
# Downloaded: flag_images/Brunei Darussalam.png
# Downloaded: flag_images/Bulgaria.png
# Downloaded: flag_images/Burkina Faso.png
# Downloaded: flag_images/Burundi.png
# Downloaded: flag_images/Cambodia.png
# Downloaded: flag_images/Cameroon.png
# Downloaded: flag_images/Canada.png
# Downloaded: flag_images/Cape Verde Islands.png
# Downloaded: flag_images/Central African Republic.png
# Downloaded: flag_images/Chad.png
# Downloaded: flag_images/Chile.png
# Downloaded: flag_images/China.png
# Downloaded: flag_images/Colombia.png
# Downloaded: flag_images/Comoro Islands.png
# Downloaded: flag_images/Congo (Dem. Rep.).png
# Downloaded: flag_images/Congo (Rep.).png
# Downloaded: flag_images/Costa Rica.png
# Downloaded: flag_images/Croatia.png
# Downloaded: flag_images/Cuba.png
# Downloaded: flag_images/Cyprus.png
# Downloaded: flag_images/Czech Republic.png
# Downloaded: flag_images/Denmark.png
# Downloaded: flag_images/Djibouti.png
# Downloaded: flag_images/Dominica.png
# Downloaded: flag_images/Dominican Republic.png
# Downloaded: flag_images/Timor-Leste.png
# Downloaded: flag_images/Ecuador.png
# Downloaded: flag_images/Egypt.png
# Downloaded: flag_images/El Salvador.png
# Downloaded: flag_images/Equatorial Guinea.png
# Downloaded: flag_images/Eritrea.png
# Downloaded: flag_images/Estonia.png
# Downloaded: flag_images/Eswatini.png
# Downloaded: flag_images/Ethiopia.png
# Downloaded: flag_images/Fiji.png
# Downloaded: flag_images/Finland.png
# Downloaded: flag_images/France.png
# Downloaded: flag_images/Gabon.png
# Downloaded: flag_images/Gambia.png
# Downloaded: flag_images/Georgia.png
# Downloaded: flag_images/Germany.png
# Downloaded: flag_images/Ghana.png
# Downloaded: flag_images/Greece.png
# Downloaded: flag_images/Grenada.png
# Downloaded: flag_images/Guatemala.png
# Downloaded: flag_images/Guinea.png
# Downloaded: flag_images/Guinea-Bissau.png
# Downloaded: flag_images/Guyana.png
# Downloaded: flag_images/Haiti.png
# Downloaded: flag_images/Honduras.png
# Downloaded: flag_images/Hungary.png
# Downloaded: flag_images/Iceland.png
# Downloaded: flag_images/India.png
# Downloaded: flag_images/Indonesia.png
# Downloaded: flag_images/Iran.png
# Downloaded: flag_images/Iraq.png
# Downloaded: flag_images/Ireland.png
# Downloaded: flag_images/Israel.png
# Downloaded: flag_images/Italy.png
# Downloaded: flag_images/Cote d'Ivoire.png
# Downloaded: flag_images/Jamaica.png
# Downloaded: flag_images/Japan.png
# Downloaded: flag_images/Jordan.png
# Downloaded: flag_images/Kazakhstan.png
# Downloaded: flag_images/Kenya.png
# Downloaded: flag_images/Kiribati.png
# Downloaded: flag_images/North Korea.png
# Downloaded: flag_images/South Korea.png
# Downloaded: flag_images/Kuwait.png
# Downloaded: flag_images/Kyrgyzstan.png
# Downloaded: flag_images/Laos.png
# Downloaded: flag_images/Latvia.png
# Downloaded: flag_images/Lebanon.png
# Downloaded: flag_images/Lesotho.png
# Downloaded: flag_images/Liberia.png
# Downloaded: flag_images/Libya.png
# Downloaded: flag_images/Liechtenstein.png
# Downloaded: flag_images/Lithuania.png
# Downloaded: flag_images/Luxembourg.png
# Downloaded: flag_images/Madagascar.png
# Downloaded: flag_images/Malawi.png
# Downloaded: flag_images/Malaysia.png
# Downloaded: flag_images/Maldives.png
# Downloaded: flag_images/Mali.png
# Downloaded: flag_images/Malta.png
# Downloaded: flag_images/Marshall Islands.png
# Downloaded: flag_images/Mauritania.png
# Downloaded: flag_images/Mauritius.png
# Downloaded: flag_images/Mexico.png
# Downloaded: flag_images/Micronesia.png
# Downloaded: flag_images/Republic of Moldova.png
# Downloaded: flag_images/Monaco.png
# Downloaded: flag_images/Mongolia.png
# Downloaded: flag_images/Montenegro.png
# Downloaded: flag_images/Morocco.png
# Downloaded: flag_images/Mozambique.png
# Downloaded: flag_images/Myanmar.png
# Downloaded: flag_images/Namibia.png
# Downloaded: flag_images/Nauru.png
# Downloaded: flag_images/Nepal.png
# Downloaded: flag_images/Netherlands.png
# Downloaded: flag_images/New Zealand.png
# Downloaded: flag_images/Nicaragua.png
# Downloaded: flag_images/Niger.png
# Downloaded: flag_images/Nigeria.png
# Downloaded: flag_images/North Macedonia.png
# Downloaded: flag_images/Norway.png
# Downloaded: flag_images/Oman.png
# Downloaded: flag_images/Pakistan.png
# Downloaded: flag_images/Palau Islands.png
# Downloaded: flag_images/State of Palestine.png
# Downloaded: flag_images/Panama.png
# Downloaded: flag_images/Papua New Guinea.png
# Downloaded: flag_images/Paraguay.png
# Downloaded: flag_images/Peru.png
# Downloaded: flag_images/Philippines.png
# Downloaded: flag_images/Poland.png
# Downloaded: flag_images/Portugal.png
# Downloaded: flag_images/Qatar.png
# Downloaded: flag_images/Romania.png
# Downloaded: flag_images/Russian Federation.png
# Downloaded: flag_images/Rwanda.png
# Downloaded: flag_images/Saint Kitts and Nevis.png
# Downloaded: flag_images/Saint Lucia.png
# Downloaded: flag_images/Saint Vincent and the Grenadines.png
# Downloaded: flag_images/Samoa.png
# Downloaded: flag_images/San Marino.png
# Downloaded: flag_images/Sao Tome and Principe.png
# Downloaded: flag_images/Saudi Arabia.png
# Downloaded: flag_images/Senegal.png
# Downloaded: flag_images/Serbia.png
# Downloaded: flag_images/Seychelles.png
# Downloaded: flag_images/Sierra Leone.png
# Downloaded: flag_images/Singapore.png
# Downloaded: flag_images/Slovakia.png
# Downloaded: flag_images/Slovenia.png
# Downloaded: flag_images/Solomon Islands.png
# Downloaded: flag_images/Somalia.png
# Downloaded: flag_images/South Africa.png
# Downloaded: flag_images/South Sudan.png
# Downloaded: flag_images/Spain.png
# Downloaded: flag_images/Sri Lanka.png
# Downloaded: flag_images/Sudan.png
# Downloaded: flag_images/Suriname.png
# Downloaded: flag_images/Sweden.png
# Downloaded: flag_images/Switzerland.png
# Downloaded: flag_images/Syria.png
# Downloaded: flag_images/Tajikistan.png
# Downloaded: flag_images/Tanzania.png
# Downloaded: flag_images/Thailand.png
# Downloaded: flag_images/Togo.png
# Downloaded: flag_images/Tonga.png
# Downloaded: flag_images/Trinidad and Tobago.png
# Downloaded: flag_images/Tunisia.png
# Downloaded: flag_images/Turkey.png
# Downloaded: flag_images/Turkmenistan.png
# Downloaded: flag_images/Tuvalu.png
# Downloaded: flag_images/Uganda.png
# Downloaded: flag_images/Ukraine.png
# Downloaded: flag_images/United Arab Emirates.png
# Downloaded: flag_images/United Kingdom.png
# Downloaded: flag_images/United States of America.png
# Downloaded: flag_images/Uruguay.png
# Downloaded: flag_images/Uzbekistan.png
# Downloaded: flag_images/Vanuatu.png
# Downloaded: flag_images/Vatican City(Holy See).png
# Downloaded: flag_images/Venezuela.png
# Downloaded: flag_images/Vietnam.png
# Downloaded: flag_images/Yemen.png
# Downloaded: flag_images/Zambia.png
# Downloaded: flag_images/Zimbabwe.png
# Downloaded: flag_images/Taiwan (Chinese Taipei).png
# Downloaded: flag_images/Hong Kong (SAR China).png
# Downloaded: flag_images/Macao (SAR China).png
# Downloaded: flag_images/Kosovo.png
